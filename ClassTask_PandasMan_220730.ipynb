# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\karan.manchanda\Downloads\Task 220730\AgentPerformance.xlsx')

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df['Date']
# Out:
# 0       2022-07-30
# 1       2022-07-30
# 2       2022-07-30
# 3       2022-07-30
# 4       2022-07-30
#            ...
# 2155    2022-07-01
# 2156    2022-07-01
# 2157    2022-07-01
# 2158    2022-07-01
# 2159    2022-07-01
# Name: Date, Length: 2160, dtype: object

# %%
date_set = pd.to_datetime(df['Date'])

# %%
date_set
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
type(date_set[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Converted_Date'] = date_set

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df['Date_Week'] = df['Converted_Date'].dt.week
# Out:
# C:\Users\KARAN~1.MAN\AppData\Local\Temp/ipykernel_20292/890431298.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['Date_Week'] = df['Converted_Date'].dt.week

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback Converted_Date  \
# 0                00:04:20            4.11               9     2022-07-30
# 1                00:28:25            3.14               7     2022-07-30
# 2                00:11:36            4.55              11     2022-07-30
# 3                00:15:46            4.71               7     2022-07-30
# 4                00:16:33            3.67               6     2022-07-30
#
#    Date_Week
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30

# %%
df_subset = df[df['Total Chats'] != 0]

# %%
df_subset.groupby(['Agent Name','Date_Week'])['Average Rating'].mean()
# Out:
# Agent Name     Date_Week
# Aditya Shinde  26           3.850
#                27           4.516
#                28           4.746
# Aditya_iot     27           4.315
#                28           4.100
#                             ...
# Wasim          30           4.298
# Zeeshan        27           4.575
#                28           4.128
#                29           4.452
#                30           4.140
# Name: Average Rating, Length: 182, dtype: float64

# %%
df_subset['Agent Name'].value_counts()
# Out:
# Shivananda Sonwane        28
# Khushboo Priya            26
# Boktiar Ahmed Bappy       26
# Jawala Prakash            25
# Manjunatha A              25
# Ayushi Mishra             24
# Ishawant Kumar            24
# Madhulika G               24
# Sanjeev Kumar             23
# Nishtha Jain              23
# Prerna Singh              22
# Shivan K                  22
# Rishav Dash               21
# Nandani Gupta             21
# Deepranjan Gupta          21
# Jaydeep Dixit             21
# Shubham Sharma            21
# Hrisikesh Neogi           21
# Maitry                    20
# Harikrishnan Shaji        19
# Bharath                   19
# Mithun S                  18
# Mahesh Sarade             18
# Aditya_iot                17
# Swati                     17
# Prabir Kumar Satapathy    17
# Prateek _iot              17
# Zeeshan                   16
# Wasim                     16
# Ameya Jain                15
# Aravind                   14
# Saikumarreddy N           13
# ...

# %%
df_subset.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Aditya Shinde             277
# Aditya_iot                231
# Ameya Jain                322
# Anirudh                    81
# Ankitjha                    5
# Anurag Tiwari               4
# Aravind                   366
# Ashad Nasim                18
# Ayushi Mishra             514
# Bharath                   369
# Boktiar Ahmed Bappy       452
# Chaitra K Hiremath         64
# Deepranjan Gupta          493
# Dibyanshu                   1
# Harikrishnan Shaji        381
# Hitesh Choudhary            1
# Hrisikesh Neogi           578
# Ishawant Kumar            338
# Jawala Prakash            439
# Jayant Kumar              127
# Jaydeep Dixit             512
# Khushboo Priya            446
# Madhulika G               469
# Mahak                       7
# Mahesh Sarade             364
# Maitry                    542
# Maneesh                     4
# Manjunatha A              413
# Mithun S                  503
# Mukesh                     19
# ...

# %%
# 4. Total feedbacks that they have received

# %%
df_subset.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Aditya Shinde             153
# Aditya_iot                131
# Ameya Jain                228
# Anirudh                    39
# Ankitjha                    3
# Anurag Tiwari               3
# Aravind                   233
# Ashad Nasim                 9
# Ayushi Mishra             329
# Bharath                   247
# Boktiar Ahmed Bappy       311
# Chaitra K Hiremath         37
# Deepranjan Gupta          312
# Dibyanshu                   0
# Harikrishnan Shaji        231
# Hitesh Choudhary            0
# Hrisikesh Neogi           367
# Ishawant Kumar            202
# Jawala Prakash            250
# Jayant Kumar               70
# Jaydeep Dixit             305
# Khushboo Priya            289
# Madhulika G               281
# Mahak                       5
# Mahesh Sarade             216
# Maitry                    347
# Maneesh                     3
# Manjunatha A              254
# Mithun S                  364
# Mukesh                     17
# ...

# %%
# 5. Agent name who have Average rating between 3.5 to 4

# %%
df[(df['Average Rating'] >= 3.5) & (df['Average Rating'] <= 4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 114, dtype: object
